# %%
#import required libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('IPL.csv')

# %%
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
data.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
data.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
data[['venue','team1','team2','stage','toss_winner','toss_decision']].unique().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15972\2495853710.py in ?()
# ----> 1 data[['venue','team1','team2','stage','toss_winner','toss_decision']].unique().sum()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
cat_columns = ['venue','team1','team2','stage','toss_winner','toss_decision']

for i in cat_columns:
    print(f'{i}:{len(data[i].unique())}')
# Out:
# venue:6
# team1:9
# team2:9
# stage:3
# toss_winner:10
# toss_decision:2

# %%
data.shape
# Out:
# (74, 20)

# %%
print(f'Your data as {data.shape[0]} rows and {data.shape[1]} columns')
# Out:
# Your data as 74 rows and 20 columns

# %%
#WHICH TEAM WON THE MOST MATCHES
data['match_winner'].unique()
# Out:
# array(['Kolkata', 'Delhi', 'Punjab', 'Gujarat', 'Rajasthan', 'Banglore',
#        'Lucknow', 'Hyderabad', 'Chennai', 'Mumbai'], dtype=object)

# %%
match_wins = data['match_winner'].value_counts()

# %%
sns.barplot(x=match_wins.values, y=match_wins.index,data=data)
plt.title("Most matches win by team")
# Out:
# Text(0.5, 1.0, 'Most matches win by team')

# %%
#Toss decision trends 
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
decisions = data['toss_decision'].value_counts()

# %%
decisions
# Out:
# toss_decision
# Field    59
# Bat      15
# Name: count, dtype: int64

# %%
sns.barplot(x=decisions.index,y=decisions.values)
plt.title("TOSS DECISION TRENDS")
# Out:
# Text(0.5, 1.0, 'TOSS DECISION TRENDS')

# %%
sns.countplot(x=data['toss_decision'])
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %%
# TOSS WINNER VS MATCH WINNER
count = data[data['toss_winner']== data['match_winner']]['match_id'].count()

percentage = (count*100)/data.shape[0]
print(percentage.round(2))
# Out:
# 48.65

# %%
# How do teams win? (Runs VS Wickets)
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
won = data['won_by'].value_counts()

# %%
total = data['won_by'].count()

# %%
won.index, won.values[0]
# Out:
# (Index(['Wickets', 'Runs'], dtype='object', name='won_by'), 37)

# %%
sns.countplot(x=data['won_by'])
plt.title("Wickets V/S Runs")
print(f"the teams wining by wickets and runs are {won.values[0]*100/total}% and {won.values[1]*100/total}% respectively ")
# Out:
# the teams wining by wickets and runs are 50.0% and 50.0% respectively

# %%
#Most Player of the match awards

# %%
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
best_award = data['player_of_the_match'].value_counts()

# %%
#Top 10
sns.barplot(y=best_award.index[:10], x=best_award.values[:10])
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
#Another way 
best_award = data['player_of_the_match'].value_counts().head(10)

# %%
sns.barplot(y=best_award.index, x=best_award.values)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
t =data['top_scorer'].max()
t
# Out:
# 'Yashasvi Jaiswal'

# %%
top = data[data['highscore'] == 140]

# %%
top['top_scorer']
# Out:
# 65    Quinton de Kock
# Name: top_scorer, dtype: object

# %%
top['highscore']
# Out:
# 65    140
# Name: highscore, dtype: int64

# %%
high = data.groupby('top_scorer')['highscore'].sum()

# %%
high
# Out:
# top_scorer
# Abhishek Sharma        122
# Aiden Markram           57
# Andre Russell          119
# David Miller            94
# David Warner           213
# Deepak Hooda           114
# Devon Conway           143
# Dinesh Karthik          66
# Faf du Plessis         257
# Hardik Pandya          154
# Ishan Kishan           180
# Jos Buttler            651
# KL Rahul               351
# Kane Williamson         57
# Liam Livingstone       239
# MS Dhoni                86
# Mitchell Marsh         152
# Moeen Ali               93
# Nitish Rana             57
# Pat Cummins             56
# Quinton de Kock        377
# Rahul Tripathi         147
# Rajat Patidar          112
# Riyan Parag             56
# Ruturaj Gaikwad         99
# Sai Sudharsan           65
# Sanju Samson            54
# Sherfane Rutherford     28
# Shikhar Dhawan         158
# Shimron Hetmyer         59
# Shivam Dube             95
# Shubman Gill           288
# Suryakumar Yadav        68
# Tilak Varma             51
# ...

# %%
high.max()
# Out:
# 651

# %%
high.sort_values(ascending=False)
# Out:
# top_scorer
# Jos Buttler            651
# Quinton de Kock        377
# KL Rahul               351
# Shubman Gill           288
# Faf du Plessis         257
# Liam Livingstone       239
# David Warner           213
# W. Saha                190
# Ishan Kishan           180
# Shikhar Dhawan         158
# Hardik Pandya          154
# Mitchell Marsh         152
# Rahul Tripathi         147
# Devon Conway           143
# Virat Kohli            131
# Abhishek Sharma        122
# Andre Russell          119
# Deepak Hooda           114
# Rajat Patidar          112
# Ruturaj Gaikwad         99
# Shivam Dube             95
# David Miller            94
# Moeen Ali               93
# MS Dhoni                86
# Suryakumar Yadav        68
# Yashasvi Jaiswal        68
# Dinesh Karthik          66
# Sai Sudharsan           65
# Shimron Hetmyer         59
# Aiden Markram           57
# Kane Williamson         57
# Nitish Rana             57
# Riyan Parag             56
# Pat Cummins             56
# ...

# %%
top_runs = high.sort_values(ascending=False).head(2)

# %%
top_runs
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
top_runs.plot(kind='barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %%
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
data['highest_wickets'] = data['best_bowling_figure'].apply(lambda x :x.split('--')[0])
data['highest_wickets'] = data['highest_wickets'].astype(int)
top_bowlers = data.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %%
#Most Matches Played by Venue
venue_count = data['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y = venue_count.index,x = venue_count.values)
# Out:
# <Axes: ylabel='venue'>

# %%
#Q1: Who won the highest margin by runs?
data[data['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
# Q2: Which player had the highest individual score?
data[data['highscore'] == data['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %%
#Q3: Which bowler had the best bowling figures?
data[data['highest_wickets'] == data['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
