# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### There are 3 errors which cannot be handled
#     - Sybtax Error
#     - Indentation Error
#     - Tab Error (When you mix tabs & spaces)

# %%
a = int(input("tell ur number:"))

print(10/a)
print("Ok i have done the division")
# Out:
# tell ur number: 8
# 1.25
# Ok i have done the division

# %%
a = int(input("tell ur number:"))

print(10/a)
print("Ok i have done the division")
# Out:
# tell ur number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 a = int(input("tell ur number:"))
# ----> 3 print(10/a)
#       4 print("Ok i have done the division")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## For Exception Handling
#
# ### Keywords : try, except, else, finally, raise

# %%
a = int(input("tell ur number:"))

try:
    print(10/a)
except Exception as err: 
    print(f"Sorry there is an error as: {err}")
else:
    print("Good there is not exception")
finally:
    print("i will run no matter what")

print("Ok i have done the division")
# Out:
# tell ur number: 0
# Sorry there is an error as: division by zero
# i will run no matter what
# Ok i have done the division

# %%
a = int(input("tell ur number:"))

try:
    print(10/a)
except Exception as err: 
    print(f"Sorry there is an error as: {err}")
else:
    print("Good there is not exception")
finally:
    print("i will run no matter what")

print("Ok i have done the division")
# Out:
# tell ur number: 8
# 1.25
# Good there is not exception
# i will run no matter what
# Ok i have done the division

# %%
age = int(input("tell your age :- "))

try:

    if age < 10 or age > 18:
        raise ValueError("your age must be between 10 and 18")
    else:
        print("welcome to the club")

except Exception as err:
    print(f"an error occured as {err}")


print("the club will start soon")
# Out:
# tell your age :-  70
# an error occured as your age must be between 10 and 18
# the club will start soon

# %% [markdown]
# # File Handling

# %% [markdown]
# - Note: We have to use open() function to open a file in python.

# %%
#Example,
p = open(r'---.txt')
print(p.read())

# %% [markdown]
# | Mode | Description                                   |
# |------|-----------------------------------------------|
# | `r`  | Read (default) – file must exist              |
# | `w`  | Write – creates a new file or overwrites it   |
# | `a`  | Append – adds data to the end of the file     |
# | `x`  | Create – creates a new file; fails if it exists |

# %% [markdown]
# | Mode  | Type     | Description |
# |-------|----------|-------------|
# | `r+`  | Text     | Read & write. File must exist. Does not overwrite. |
# | `w+`  | Text     | Read & write. Overwrites file or creates new. |
# | `a+`  | Text     | Read & append. Writes at end; reading starts at beginning. |
# nning. |

# %% [markdown]
# - To Create and add few lines in that file

# %%
# Open the folder in which you want to create file 

r = open("Super_man.txt",'w')

r.write("Hello this is Sameer and I am writing inside a text file.")
r.close()

# %%
# Append more lines in same fFileExistsError

r = open("Super_man.txt",'a')

r.write("And her we go , appending few more lines inside the file")
r.close()
